# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(4, 3, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 99)
# Out:
# np.float64(11.004192308601441)

# %%
np.percentile(vals, 60)
# Out:
# np.float64(0.13786240839836508)

# %%
np.percentile(vals, 2)
# Out:
# np.float64(-1.0410726222189)

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?
